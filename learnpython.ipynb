# %%
from dataclasses import dataclass


@dataclass(frozen=True)
class Emp:
   id:float  # here this class acts like instance variable and not class variable
   name:str

a = Emp(100,'anand')
b = Emp(101, 'jp')
c = Emp(102, 'jass')

mySet: set[Emp] ={a,a,b}
print(mySet)
mySecondSet={b,c}




print(mySecondSet.difference(mySet))


#  simple set check

x = 5
if a in mySet:
   print(f"mySet contains a: {x}")


if a in mySecondSet:
   print(f"mySet contains b: {x}")


# filter

filtered = {item for item in mySet if item.id > 100 }
print(filtered)


# iterate through a set
for item in mySet:
   print(item)

# %%
dic: dict[Emp,int] = {}
dic[a] = 1
dic[b] =2
dic[c]=3


print(dic[b])

if b in dic:
    print("b is present")

print(len(dic))

dic.pop(b)
dic.pop(a)
status = dic.pop(a,None)
print(status)

dic.update({a:55}) # update just adds another item 
print(dic[a])

# iterate through a dictionary
for key,value in dic.items():
    print(key)

# %%
# uusing dictionary
newdict:dict[Emp,int] ={}
cmpdict:dict[Emp,int]={}

empA= Emp("abba",5)
empB= Emp("abba",8)

newdict[empA] = 1
cmpdict[empB] = 1

print(newdict==cmpdict)


xx = []
xx.append(empB)
xx.append(empA)



uu = []
uu.append(empA)
uu.append(empB)

print(xx==uu)

# %%
# tuple example
mytpl = (empA, empB)
print(mytpl[1])

tpldict ={}
tpldict[mytpl]=1
print(tpldict)

# %%
# lambda functions
add = lambda x,y,z: x+y+z

add(1,2,3)

sq = [1,2,3]
sqs= list(map(lambda n: n*n,sq))
print(sqs)
div3 = list(filter(lambda x: x%3==0,sqs))
print(div3)

# %%
names = ["Alice", "Bob", "Charlie", "Dana"]
scores = [90, 55, 72, 88]

# Pair names with scores
paired = dict(zip(names, scores))
print(paired)

# %%
# list vs tuples
# array vs list

x = (5,"noanand")
print(type(x))


y =(5,"oanand")

print(x==y)
# Out:
# <class 'tuple'>
# False

# %%
# default dictionary
from collections import defaultdict


cdict:dict[str,str] ={}
# print(cdict["4"])



dd=defaultdict(list)
print(dd["five"])
