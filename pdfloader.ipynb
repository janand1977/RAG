# %%
pip install pypdf2  pandas

# %%
import PyPDF2
import os
import pandas

file_path= "C:\\Users\\janan\\Downloads\\Resume-FullStack.pdf"
with open(file_path,"rb") as file:
    reader = PyPDF2.PdfReader(file)

for page in reader.pages:
    print(reader.metadata.get("/Producer"))
